# %%
from PIL import Image 

for i in range(0, 100) : 
    img = Image.open('./data2/raw/train/images/image_{:05d}.png'.format(i+1))
    img.save('./data2/raw/train/images/image_{:05d}.png'.format(i+10001))
    print('./data2/raw/train/images/image_{:05d}.png'.format(i+10001))
# Out:
# ./data2/raw/train/images/image_10001.png
# ./data2/raw/train/images/image_10002.png
# ./data2/raw/train/images/image_10003.png
# ./data2/raw/train/images/image_10004.png
# ./data2/raw/train/images/image_10005.png
# ./data2/raw/train/images/image_10006.png
# ./data2/raw/train/images/image_10007.png
# ./data2/raw/train/images/image_10008.png
# ./data2/raw/train/images/image_10009.png
# ./data2/raw/train/images/image_10010.png
# ./data2/raw/train/images/image_10011.png
# ./data2/raw/train/images/image_10012.png
# ./data2/raw/train/images/image_10013.png
# ./data2/raw/train/images/image_10014.png
# ./data2/raw/train/images/image_10015.png
# ./data2/raw/train/images/image_10016.png
# ./data2/raw/train/images/image_10017.png
# ./data2/raw/train/images/image_10018.png
# ./data2/raw/train/images/image_10019.png
# ./data2/raw/train/images/image_10020.png
# ./data2/raw/train/images/image_10021.png
# ./data2/raw/train/images/image_10022.png
# ./data2/raw/train/images/image_10023.png
# ...

# %%
for i in range(0, 10) : 
    img = Image.open('./data2/raw/valid/images/image_{:05d}.png'.format(i+101))
    img.save('./data2/raw/valid/images/image_{:05d}.png'.format(i+1001))
    print('./data2/raw/valid/images/image_{:05d}.png'.format(i+1001))
# Out:
# ./data2/raw/valid/images/image_01001.png
# ./data2/raw/valid/images/image_01002.png
# ./data2/raw/valid/images/image_01003.png
# ./data2/raw/valid/images/image_01004.png
# ./data2/raw/valid/images/image_01005.png
# ./data2/raw/valid/images/image_01006.png
# ./data2/raw/valid/images/image_01007.png
# ./data2/raw/valid/images/image_01008.png
# ./data2/raw/valid/images/image_01009.png
# ./data2/raw/valid/images/image_01010.png

# %%
for i in range(0, 100) : 
    img = Image.open('./data2/raw/train/images/image_{:05d}.png'.format(i+10001))
    print(img.height)
# Out:
# 71
# 104
# 41
# 39
# 37
# 33
# 31
# 33
# 33
# 35
# 32
# 32
# 32
# 35
# 33
# 35
# 35
# 35
# 33
# 33
# 35
# 34
# 34
# 33
# 33
# 35
# 33
# 41
# 30
# 31
# 33
# 35
# 33
# 31
# 33
# 33
# 35
# 32
# 32
# 35
# 33
# 35
# 35
# 35
# 33
# 33
# 35
# 34
# 34
# 33
# 33
# 35
# 33
# 33
# 74
# 38
# 31
# 33
# 31
# 32
# 31
# 33
# 33
# 33
# 31
# 33
# 31
# 31
# 32
# 33
# 33
# 32
# 33
# 31
# 31
# 31
# 33
# 33
# 31
# 33
# 31
# 31
# 32
# 33
# 33
# 32
# 33
# 31
# 31
# 31
# 70
# 70
# 38
# 34
# 32
# 32
# 32
# 32
# 38
# 32
