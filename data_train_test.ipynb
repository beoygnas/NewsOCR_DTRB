# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pwd
# Out:
# '/content'

# %%
ls /content/drive/MyDrive/ColabNotebooks/
# Out:
# assignment1/  data/             hw3_object_detection/  t5/
# d2l/          DL_finalproject/  img/                   t5_2/
# d2l-pytorch/  FashionMNIST/     lstm/

# %% [markdown]
# ## **학습 데이터생성**

# %%
# !git clone https://github.com/Belval/TextRecognitionDataGenerator.git
# Out:
# Cloning into 'TextRecognitionDataGenerator'...
# remote: Enumerating objects: 1565, done.
# remote: Total 1565 (delta 0), reused 0 (delta 0), pack-reused 1565
# Receiving objects: 100% (1565/1565), 152.62 MiB | 15.61 MiB/s, done.
# Resolving deltas: 100% (651/651), done.
# Checking out files: 100% (576/576), done.

# %%
cd /content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr/TextRecognitionDataGenerator
# Out:
# /content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr/TextRecognitionDataGenerator

# %%
# !pip install -r requirements.txt

# %%
# !pip install Pillow==9.3.0

# %%
# !python3 trdg/run.py \
  -c 100 \
  -l en \
  --output_dir '/content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr/data/en/raw/train'
# Out:
# 2022-11-29 07:23:12.569978: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 100% 100/100 [00:05<00:00, 19.41it/s]

# %%
# !python3 trdg/run.py \
  -c 10 \
  -l en \
  --output_dir '/content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr/data/en/raw/valid'
# Out:
# 2022-11-29 07:23:22.041645: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 100% 10/10 [00:00<00:00, 18.91it/s]

# %%
# !python3 trdg/run.py \
  -c 10 \
  -l en \
  --output_dir '/content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr/data/en/raw/test'
# Out:
# 2022-11-29 07:23:26.573582: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 100% 10/10 [00:00<00:00, 42.96it/s]

# %% [markdown]
# ## **학습데이터 변환**

# %%
cd /content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr
# Out:
# /content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr

# %%
# !git clone https://github.com/DaveLogs/TRDG2DTRB.git
# Out:
# Cloning into 'TRDG2DTRB'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 43 (delta 10), reused 21 (delta 3), pack-reused 0
# Unpacking objects: 100% (43/43), done.

# %%
cd /content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr/TRDG2DTRB
# Out:
# /content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr/TRDG2DTRB

# %%
# !python convert.py \
  --input_path ../data/ko/raw/train \
  --output_path ../data/ko/real/train
# Out:
# input path:  /content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr/data/ko/raw/train
# output path:  /content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr/data/ko/real/train
# Total file count:  100
# 100 / 100 Processing !!
# Conversion complete!

# %%
# !python convert.py \
  --input_path ../data/ko/raw/valid \
  --output_path ../data/ko/real/valid
# Out:
# input path:  /content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr/data/ko/raw/valid
# output path:  /content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr/data/ko/real/valid
# Total file count:  10
#
# Conversion complete!

# %%
# !python convert.py \
  --input_path ../data/ko/raw/test \
  --output_path ../data/ko/real/test
# Out:
# input path:  /content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr/data/ko/raw/test
# output path:  /content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr/data/ko/real/test
# Total file count:  10
#
# Conversion complete!

# %% [markdown]
# ## **학습데이터 lmdb화**

# %%
 cd /content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr/deep-text-recognition-benchmark/
# Out:
# /content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr/deep-text-recognition-benchmark

# %%
# !pip install torch torchvision
# !pip install lmdb pillow nltk natsort
# !pip install fire
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 87 kB 5.6 MB/s
# ...
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115943 sha256=64fcc54e2901896c99c3175227e3267f5f9c75743cba540925ac3cb876c7d2f0
#   Stored in directory: /root/.cache/pip/wheels/1f/10/06/2a990ee4d73a8479fe2922445e8a876d38cfbfed052284c6a1
# Successfully built fire
# ...

# %%
# !python3 create_lmdb_dataset.py \
        --inputPath ../data/raw/train/ \
        --gtFile ../data/raw/train/gt.txt \
        --outputPath ../data/lmdb/train/
# Out:
# Traceback (most recent call last):
#   File "create_lmdb_dataset.py", line 87, in <module>
#     fire.Fire(createDataset)
#   File "/usr/local/lib/python3.8/dist-packages/fire/core.py", line 141, in Fire
#     component_trace = _Fire(component, args, parsed_flag_args, context, name)
#   File "/usr/local/lib/python3.8/dist-packages/fire/core.py", line 466, in _Fire
#     component, remaining_args = _CallAndUpdateTrace(
#   File "/usr/local/lib/python3.8/dist-packages/fire/core.py", line 681, in _CallAndUpdateTrace
#     component = fn(*varargs, **kwargs)
#   File "create_lmdb_dataset.py", line 58, in createDataset
#     imageBin = f.read()
# KeyboardInterrupt
# ^C

# %%
# !python3 create_lmdb_dataset.py \
        --inputPath ../data/raw/valid/ \
        --gtFile ../data/raw/valid/gt.txt \
        --outputPath ../data/lmdb/valid/
# Out:
# Created dataset with 10 samples

# %%
# !python3 create_lmdb_dataset.py \
        --inputPath ../data/raw/valid/ \
        --gtFile ../data/raw/valid/gt.txt \
        --outputPath ../data/lmdb/valid/
# Out:
# Written 1000 / 1000
# Created dataset with 1000 samples

# %% [markdown]
# ## **모델 학습**

# %%
 cd /content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr/deep-text-recognition-benchmark/
# Out:
# /content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr/deep-text-recognition-benchmark

# %%
# !python3 train.py \
    --train_data ../data_news/lmdb/train \
    --valid_data ../data_news/lmdb/valid \
    --Transformation TPS \
    --FeatureExtraction ResNet \
    --SequenceModeling BiLSTM \
    --Prediction Attn \
    --saved_model /content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr/deep-text-recognition-benchmark/saved_models/TRBA/best_accuracy.pth \
    --batch_max_length 45 \
    --batch_size 128 \
    --data_filtering_off \
    --num_iter 10000 \
    --valInterval 500 \
    --FT
# Out:
# --------------------------------------------------------------------------------
# dataset_root: ../data_news/lmdb/train
# opt.select_data: ['/']
# opt.batch_ratio: ['1']
# --------------------------------------------------------------------------------
# dataset_root:    ../data_news/lmdb/train	 dataset: /
# sub-directory:	/.	 num samples: 100
# num total samples of /: 100 x 1.0 (total_data_usage_ratio) = 100
# num samples of / per batch: 128 x 1.0 (batch_ratio) = 128
# --------------------------------------------------------------------------------
# Total_batch_size: 128 = 128
# --------------------------------------------------------------------------------
# dataset_root:    ../data_news/lmdb/valid	 dataset: /
# sub-directory:	/.	 num samples: 10
# --------------------------------------------------------------------------------
# model input parameters 32 100 20 1 512 256 1010 45 TPS ResNet BiLSTM Attn
# ...

# %%
# Out:
# --------------------------------------------------------------------------------
# dataset_root: ../data_aihub/lmdb/valid
# opt.select_data: ['/']
# opt.batch_ratio: ['1']
# --------------------------------------------------------------------------------
# dataset_root:    ../data_aihub/lmdb/valid	 dataset: /
# sub-directory:	/.	 num samples: 1000
# num total samples of /: 1000 x 1.0 (total_data_usage_ratio) = 1000
# num samples of / per batch: 192 x 1.0 (batch_ratio) = 192
# --------------------------------------------------------------------------------
# Total_batch_size: 192 = 192
# --------------------------------------------------------------------------------
# dataset_root:    ../data_aihub/lmdb/test	 dataset: /
# sub-directory:	/.	 num samples: 1000
# --------------------------------------------------------------------------------
# model input parameters 32 100 20 1 512 256 1009 45 TPS ResNet BiLSTM CTC
# ...

# %%
# !python3 train.py \
    --train_data ../data_aihub/lmdb/train \
    --valid_data ../data_aihub/lmdb/valid \
    --Transformation TPS \
    --FeatureExtraction ResNet \
    --SequenceModeling BiLSTM \
    --Prediction CTC \
    --num_iter 100000 \
    --valInterval 100 \
    --batch_max_length 45 \
    --batch_size 64 \
    --data_filtering_off
# Out:
# --------------------------------------------------------------------------------
# dataset_root: ../data_aihub/lmdb/train
# opt.select_data: ['/']
# opt.batch_ratio: ['1']
# --------------------------------------------------------------------------------
# dataset_root:    ../data_aihub/lmdb/train	 dataset: /
# sub-directory:	/.	 num samples: 10000
# num total samples of /: 10000 x 1.0 (total_data_usage_ratio) = 10000
# num samples of / per batch: 64 x 1.0 (batch_ratio) = 64
# --------------------------------------------------------------------------------
# Total_batch_size: 64 = 64
# --------------------------------------------------------------------------------
# dataset_root:    ../data_aihub/lmdb/valid	 dataset: /
# sub-directory:	/.	 num samples: 1000
# --------------------------------------------------------------------------------
# model input parameters 32 100 20 1 512 256 1009 45 TPS ResNet BiLSTM CTC
# ...

# %%
# !python3 train.py \
    --train_data ../data_aihub/lmdb/train \
    --valid_data ../data_aihub/lmdb/valid \
    --Transformation TPS \
    --FeatureExtraction VGG \
    --SequenceModeling BiLSTM \
    --Prediction Attn \
    --num_iter 100000 \
    --valInterval 500 \
    --batch_max_length 45 \
    --batch_size 128 \
    --data_filtering_off
# Out:
# --------------------------------------------------------------------------------
# dataset_root: ../data_aihub/lmdb/train
# opt.select_data: ['/']
# opt.batch_ratio: ['1']
# --------------------------------------------------------------------------------
# dataset_root:    ../data_aihub/lmdb/train	 dataset: /
# sub-directory:	/.	 num samples: 10000
# num total samples of /: 10000 x 1.0 (total_data_usage_ratio) = 10000
# num samples of / per batch: 128 x 1.0 (batch_ratio) = 128
# --------------------------------------------------------------------------------
# Total_batch_size: 128 = 128
# --------------------------------------------------------------------------------
# dataset_root:    ../data_aihub/lmdb/valid	 dataset: /
# sub-directory:	/.	 num samples: 1000
# --------------------------------------------------------------------------------
# model input parameters 32 100 20 1 512 256 1010 45 TPS VGG BiLSTM Attn
# ...

# %%
# !python3 train.py \
        --train_data '../lmdb/train' \
        --valid_data '../lmdb/valid' \
        --Transformation None \
        --FeatureExtraction "VGG" \
        --SequenceModeling "BiLSTM" \
        --Prediction "CTC" \
        --input_channel 1 \
        --output_channel 256 \
        --hidden_size 256 \
        --saved_model "./models/korean_g2.pth" \
        --data_filtering_off \
        --FT
# Out:
# --------------------------------------------------------------------------------
# dataset_root: ../lmdb/train
# opt.select_data: ['/']
# opt.batch_ratio: ['1']
# --------------------------------------------------------------------------------
# dataset_root:    ../lmdb/train	 dataset: /
# sub-directory:	/.	 num samples: 100
# num total samples of /: 100 x 1.0 (total_data_usage_ratio) = 100
# num samples of / per batch: 192 x 1.0 (batch_ratio) = 192
# --------------------------------------------------------------------------------
# Total_batch_size: 192 = 192
# --------------------------------------------------------------------------------
# dataset_root:    ../lmdb/valid	 dataset: /
# sub-directory:	/.	 num samples: 10
# --------------------------------------------------------------------------------
# No Transformation module specified
# model input parameters 32 100 20 1 256 256 1009 25 None VGG BiLSTM CTC
# loading pretrained model from ./models/korean_g2.pth
# Model:
# ...

# %%
# !python3 train.py \
  --train_data ../lmdb/train \
  --valid_data ../lmdb/valid \
	--Transformation TPS \
  --FeatureExtraction ResNet \
  --SequenceModeling BiLSTM \
  --Prediction CTC \
	--data_filtering_off 
  # --workers 0 \
  # --imgH 64 \
  # --imgW 200
# Out:
# --------------------------------------------------------------------------------
# dataset_root: ../lmdb/train
# opt.select_data: ['/']
# opt.batch_ratio: ['1']
# --------------------------------------------------------------------------------
# dataset_root:    ../lmdb/train	 dataset: /
# sub-directory:	/.	 num samples: 100
# num total samples of /: 100 x 1.0 (total_data_usage_ratio) = 100
# num samples of / per batch: 192 x 1.0 (batch_ratio) = 192
# --------------------------------------------------------------------------------
# Total_batch_size: 192 = 192
# --------------------------------------------------------------------------------
# dataset_root:    ../lmdb/valid	 dataset: /
# sub-directory:	/.	 num samples: 10
# --------------------------------------------------------------------------------
# model input parameters 32 100 20 1 512 256 1009 25 TPS ResNet BiLSTM CTC
# Skip Transformation.LocalizationNetwork.localization_fc2.weight as it is already initialized
# ...

# %%
# !python3 train.py \
    --train_data ../data/lmdb/train \
    --valid_data ../data/lmdb/valid \
    --Transformation TPS \
    --FeatureExtraction ResNet \
    --SequenceModeling BiLSTM \
    --Prediction Attn \
    --num_iter 100000 \
    --valInterval 500 \
    --batch_max_length 45 \
    --batch_size 128 \
    --data_filtering_off
# Out:
# --------------------------------------------------------------------------------
# dataset_root: ../data/lmdb/train
# opt.select_data: ['/']
# opt.batch_ratio: ['1']
# --------------------------------------------------------------------------------
# dataset_root:    ../data/lmdb/train	 dataset: /
# sub-directory:	/.	 num samples: 10100
# num total samples of /: 10100 x 1.0 (total_data_usage_ratio) = 10100
# num samples of / per batch: 128 x 1.0 (batch_ratio) = 128
# --------------------------------------------------------------------------------
# Total_batch_size: 128 = 128
# --------------------------------------------------------------------------------
# dataset_root:    ../data/lmdb/valid	 dataset: /
# sub-directory:	/.	 num samples: 1010
# --------------------------------------------------------------------------------
# model input parameters 32 100 20 1 512 256 1010 45 TPS ResNet BiLSTM Attn
# ...

# %%
# !python3 train.py \
    --train_data ../newdata/lmdb/train \
    --valid_data ../newdata/lmdb/valid \
    --Transformation TPS \
    --FeatureExtraction ResNet \
    --SequenceModeling BiLSTM \
    --Prediction Attn \
    --num_iter 100000 \
    --valInterval 500 \
    --batch_max_length 43 \
    --batch_size 128 \
    --data_filtering_off
# Out:
# --------------------------------------------------------------------------------
# dataset_root: ../newdata/lmdb/train
# opt.select_data: ['/']
# opt.batch_ratio: ['1']
# --------------------------------------------------------------------------------
# dataset_root:    ../newdata/lmdb/train	 dataset: /
# sub-directory:	/.	 num samples: 5000
# num total samples of /: 5000 x 1.0 (total_data_usage_ratio) = 5000
# num samples of / per batch: 128 x 1.0 (batch_ratio) = 128
# --------------------------------------------------------------------------------
# Total_batch_size: 128 = 128
# --------------------------------------------------------------------------------
# dataset_root:    ../newdata/lmdb/valid	 dataset: /
# sub-directory:	/.	 num samples: 525
# --------------------------------------------------------------------------------
# model input parameters 32 100 20 1 512 256 1010 43 TPS ResNet BiLSTM Attn
# ...

# %%
# !nvidia-smi
# Out:
# Sun Dec  4 17:42:47 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P0    26W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !cat /etc/issue.net
# Out:
# Ubuntu 18.04.6 LTS

# %% [markdown]
# ## **모델 테스트**

# %%
 cd /content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr/deep-text-recognition-benchmark/
# Out:
# /content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr/deep-text-recognition-benchmark

# %%
# !python3 test.py \
  --eval_data /content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr/data/lmdb/test/ \
  --benchmark_all_eval \
  --Transformation TPS \
  --FeatureExtraction ResNet \
  --SequenceModeling BiLSTM \
  --Prediction Attn \
  --saved_model ./saved_models/TPS-ResNet-BiLSTM-Attn-Seed1111/best_accuracy.pth \
# Out:
# python3: can't open file 'test.py': [Errno 2] No such file or directory

# %%
# !python3 demo.py \
--Transformation TPS \
--FeatureExtraction ResNet \
--SequenceModeling BiLSTM \
--Prediction Attn \
--batch_max_length 50 \
--saved_model ./saved_models/TRBA/best_accuracy.pth \
--image_folder ../data_aihub/raw/test/images 

# --image_folder ../data_news/raw/train/images

# --image_folder /content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr/deep-text-recognition-benchmark/demo_image2 \
# Out:
# python3: can't open file 'demo.py': [Errno 2] No such file or directory

# %%
# !python3 test.py \
--Transformation TPS \
--FeatureExtraction ResNet \
--SequenceModeling BiLSTM \
--Prediction Attn \
--batch_max_length 50 \
--saved_model ./saved_models/TPS-ResNet-BiLSTM-Attn-Seed1111/best_accuracy.pth \
--eval_data ../newdata/lmdb/test \


# --image_folder ../data_news/raw/train/images
# --image_folder /content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr/deep-text-recognition-benchmark/demo_image2 \
# Out:
# python3: can't open file 'test.py': [Errno 2] No such file or directory

# %%
# !python3 test.py \
--Transformation None \
--FeatureExtraction VGG \
--SequenceModeling BiLSTM \
--Prediction CTC \
--batch_max_length 50 \
--saved_model ./saved_models/None-VGG-BiLSTM-CTC-Seed1111/best_accuracy.pth \
--eval_data ../newdata/lmdb/test \
--input_channel 1 \
--output_channel 256 \
--hidden_size 256 
# --image_folder ../newdata/raw/
# --image_folder ../data_news/raw/train/images
# --image_folder /content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr/deep-text-recognition-benchmark/demo_image2 \
# Out:
# python3: can't open file 'test.py': [Errno 2] No such file or directory

# %%
# !python3 demo.py \
--Transformation None \
--FeatureExtraction VGG \
--SequenceModeling BiLSTM \
--Prediction CTC \
--batch_max_length 50 \
--saved_model ./saved_models/None-VGG-BiLSTM-CTC-Seed1111/best_accuracy.pth \
--image_folder ../data_tmp/\
--input_channel 1 \
--output_channel 256 \
--hidden_size 256 

# --image_folder ../data_news/raw/train/images
# --image_folder /content/drive/MyDrive/ColabNotebooks/DL_finalproject/EasyOcr/deep-text-recognition-benchmark/demo_image2 \
# Out:
# No Transformation module specified
# model input parameters 32 100 20 1 256 256 1009 50 None VGG BiLSTM CTC
# loading pretrained model from ./saved_models/None-VGG-BiLSTM-CTC-Seed1111/best_accuracy.pth
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# ../data_tmp/img1/column/c0_s0_1.png	산업단지                     	0.9962
# ../data_tmp/img1/column/c0_s0_2.png	계획                       	1.0000
# ../data_tmp/img1/column/c0_s0_3.png	심의위                      	0.9704
# ../data_tmp/img1/column/c0_s0_4.png	통과                       	0.9760
# ../data_tmp/img1/column/c0_s1_1.png	부산해운다다.                  	0.0656
# ../data_tmp/img1/column/c0_s1_2.png	센립자구                     	0.2806
# ../data_tmp/img1/column/c0_s1_3.png	도시점단산                    	0.5798
# ...

# %%
# !python3 demo.py \
--Transformation TPS \
--FeatureExtraction ResNet \
--SequenceModeling BiLSTM \
--Prediction Attn \
--batch_max_length 50 \
--saved_model ./saved_models/TPS-ResNet-BiLSTM-Attn-Seed1111/best_accuracy.pth \
--image_folder ../data_tmp/
# Out:
# python3: can't open file 'demo.py': [Errno 2] No such file or directory
